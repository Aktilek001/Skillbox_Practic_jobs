# %%
import math

# %%
math.sin(0)
# Out:
# 0.0

# %%
math.cos(0)
# Out:
# 1.0

# %%
math.cos(2*3.14)
# Out:
# 0.9999949269133752

# %%
math.cos(2*math.pi)
# Out:
# 1.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import cowsay

cowsay.cow(str(math.pi))
# Out:
#   _________________
# | 3.141592653589793 |
# ...
#                  \
#                   \
#                     ^__^
#                     (oo)\_______
#                     (__)\       )\/\
#                         ||----w |
#                         ||     ||

# %%
# !pwd
# Out:
# /Users/petremelianov/Module_cmd

# %%
# !ls -l
# Out:
# total 224
# -rw-r--r--@ 1 peter  staff  33530 Oct 25 16:50 anna_words.txt
# -rw-r--r--  1 peter  staff     84 Oct 25 19:07 count_words.py
# -rw-r--r--  1 peter  staff  63202 Oct 25 17:40 lesson_1.ipynb
# -rw-r--r--  1 peter  staff   2908 Oct 25 19:59 lesson_5.ipynb
# -rw-r--r--  1 peter  staff     11 Oct 25 19:02 zen.py

# %%
# !pip install cowsay
# Out:
# ...
#   Using cached cowsay-4.0-py2.py3-none-any.whl (24 kB)
# ...
